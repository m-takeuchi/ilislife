# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

# %%
ls data
# Out:
# 160725-143700.dat  160727-170139.dat  160727-174126.dat  160727-182305.dat
# 160725-143859.dat  160727-170517.dat  160727-174357.dat  160727-182506.dat
# 160725-143953.dat  160727-170633.dat  160727-175808.dat  160729-162421.dat
# 160725-144223.dat  160727-171000.dat  160727-180436.dat  160729-162437.dat
# 160725-144326.dat  160727-171220.dat  160727-180527.dat  160801-113539.dat
# 160725-151154.dat  160727-172935.dat  160727-181131.dat  160801-120813.dat
# 160725-174600.dat  160727-173142.dat  160727-181241.dat  Untitled.ipynb
# 160725-175032.dat  160727-173637.dat  160727-181932.dat
# 160725-180708.dat  160727-173723.dat  160727-182214.dat

# %%
# datafile = 'data/160725-171642.dat'
# datafile = 'data/160720-190506.dat'
datafile = 'data/160729-162437.dat'
base = datafile.rsplit('.dat')[0]
pdffile = base+'.pdf'
jpgfile = base+'.jpg'

# %%
data = pd.read_csv(datafile, delimiter='\t', comment='#',names=['date','time','Ve','Ig','Ic'],\
           dtype={'Ve':'float64','Ig':'float64','Ic':'float64'})

# %%
### Omit abnormal data

ignore1 = data['Ig'].abs() > 1e+10
ignore2 = data['Ic'] > 1e+10
# data[(ignore1 | ignore2) == False]
data = data[(ignore1 | ignore2) == False]

# %%
# fig = plt.figure()
gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])
# ax1 = fig.add_subplot(211)
# ax2 = fig.add_subplot(212)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])




time_h = data['time']/3600

ax1.set_ylabel('Ve (kV)')
ax1.set_ylim(0,10)
ax1.set_xticklabels('')
ax2.set_ylabel('Ig, Ic (1e-5*V)')
ax2.set_xlabel('Time (h)')

ax1.plot(time_h, data['Ve']/1e3, 'k-')
ax2.plot(time_h, data['Ig']/1e5, 'g-')
ax2.plot(time_h, data['Ic']/1e5, 'b-')

# plt.savefig(pdffile)
# plt.savefig(jpgfile)

# %%
# Out:
# <bound method GridSpec.get_subplot_params of <matplotlib.gridspec.GridSpec object at 0x114f4d320>>

# %%
data
# Out:
#                    date  time    Ve        Ig        Ic
# 0    160725-17:16:48.62     0     0  0.000000  0.000000
# 1    160725-17:16:49.56     1    50  0.000003  0.000008
# 2    160725-17:16:50.57     2   100  0.000000  0.000007
# 3    160725-17:16:51.56     3   150 -0.000005  0.000007
# 4    160725-17:16:52.55     4   200 -0.000006  0.000008
# 5    160725-17:16:53.56     5   250  0.000004  0.000007
# 6    160725-17:16:54.57     6   300 -0.000008  0.000007
# 7    160725-17:16:55.58     7   350  0.000003  0.000008
# 8    160725-17:16:56.57     8   400 -0.000010  0.000004
# 9    160725-17:16:57.57     9   450 -0.000004  0.000007
# 10   160725-17:16:58.58    10   500 -0.000006  0.000006
# 11   160725-17:16:59.57    11   550  0.000005  0.000007
# 12   160725-17:17:00.58    12   600  0.000004  0.000008
# 13   160725-17:17:01.57    13   650 -0.000001  0.000007
# 14   160725-17:17:02.58    14   700 -0.000002  0.000007
# 15   160725-17:17:03.59    15   750 -0.000003  0.000008
# 16   160725-17:17:04.60    16   800 -0.000006  0.000009
# 17   160725-17:17:05.60    17   850  0.000000  0.000009
# 18   160725-17:17:06.61    18   900 -0.000005  0.000007
# 19   160725-17:17:07.62    19   950  0.000000  0.000008
# 20   160725-17:17:08.61    20  1000 -0.000006  0.000007
# 21   160725-17:17:09.62    21  1050  0.000002  0.000008
# 22   160725-17:17:10.63    22  1100  0.000004  0.000010
# 23   160725-17:17:11.63    23  1150  0.000004  0.000006
# 24   160725-17:17:12.63    24  1200 -0.000006  0.000007
# 25   160725-17:17:13.63    25  1250 -0.000001  0.000005
# 26   160725-17:17:14.64    26  1300 -0.000002  0.000008
# 27   160725-17:17:15.65    27  1350 -0.000003  0.000007
# 28   160725-17:17:16.64    28  1400 -0.000005  0.000006
# 29   160725-17:17:17.65    29  1450 -0.000004  0.000006
# ..                  ...   ...   ...       ...       ...
# 286  160725-17:21:35.55   286  4500 -0.000004  0.000008
# 287  160725-17:21:36.54   287  4500  0.000000  0.000009
# 288  160725-17:21:37.55   288  4500 -0.000004  0.000008
# 289  160725-17:21:38.55   289  4500 -0.000004  0.000009
# 290  160725-17:21:39.55   290  4500 -0.000004  0.000010
# 291  160725-17:21:40.55   291  4500 -0.000003  0.000010
# 292  160725-17:21:41.56   292  4500 -0.000004  0.000011
# 293  160725-17:21:42.55   293  4500 -0.000002  0.000009
# 294  160725-17:21:43.56   294  4500 -0.000001  0.000007
# 295  160725-17:21:44.55   295  4500 -0.000005  0.000010
# 296  160725-17:21:45.56   296  4500 -0.000002  0.000010
# 297  160725-17:21:46.57   297  4500 -0.000004  0.000008
# 298  160725-17:21:47.58   298  4500 -0.000003  0.000010
# 299  160725-17:21:48.57   299  4500 -0.000003  0.000009
# 300  160725-17:21:49.57   300  4500 -0.000007  0.000010
# 301  160725-17:21:50.57   301  4500 -0.000008  0.000009
# 302  160725-17:21:51.57   302  4500 -0.000003  0.000010
# 303  160725-17:21:52.57   303  4500  0.000000  0.000011
# 304  160725-17:21:53.57   304  4500 -0.000004  0.000010
# 305  160725-17:21:54.58   305  4500 -0.000005  0.000009
# 306  160725-17:21:55.59   306  4500 -0.000004  0.000009
# 307  160725-17:21:56.58   307  4500 -0.000003  0.000010
# 308  160725-17:21:57.59   308  4500 -0.000003  0.000009
# 309  160725-17:21:58.60   309  4500 -0.000001  0.000010
# 310  160725-17:21:59.59   310  4500 -0.000004  0.000011
# 311  160725-17:22:00.59   311  4500 -0.000003  0.000012
# 312  160725-17:22:01.59   312  4500 -0.000002  0.000010
# 313  160725-17:22:02.59   313  4500  0.000000  0.000011
# 314  160725-17:22:03.60   314  4500 -0.000007  0.000003
# 315  160725-17:22:04.59   315  4500 -0.000001  0.000010
#
# [316 rows x 5 columns]
